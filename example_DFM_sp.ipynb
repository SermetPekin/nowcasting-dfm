# %%
import pandas as pd

from dfm_sp import Options, run_with_options, run
from dfm_sp.core.summarize import summarize
from dfm_sp.sp_plots import (
    plot_transformed_data_one,
    plot_loglik,
    plot_common,
    plot_projection_x_over_y,
)

# -------------------------------------------------User Inputs
options = Options(
    vintage="2016-06-29",
    country="US",
    sample_start="2000-01-01",
    spec_file_name="Spec_US_example.xls",
    threshold=1e-4,
    use_cache=True,
    max_iter=5000,
)

# %%
# Set dataframe to full view
pd.set_option("display.expand_frame_repr", False)

# -------------------------------------------------Load model specification and dataset.
Spec, X, Time, Z = run_with_options(options)

# Summarize dataset
summarize(X, Time, Spec)
# Out:
#  Table 1: Model specification
#
#               SeriesID                   SeriesName                 Units              UnitsTransformed
# 0               PAYEMS           Payroll Employment  Thousands of Persons           Change (Difference)
# 1               JTSJOL                 Job Openings             Thousands           Change (Difference)
# 2             CPIAUCSL         Consumer Price Index                 Index                Percent Change
# 3              DGORDER         Durable Goods Orders           $, Millions                Percent Change
# 4                RSAFS                 Retail Sales           $, Millions                Percent Change
# 5               UNRATE            Unemployment Rate                     %           Change (Difference)
# 6                HOUST               Housing Starts    Thousands of Units                Percent Change
# 7               INDPRO        Industrial Production                 Index                Percent Change
# 8              DSPIC96              Personal Income   Chained $, Billions                Percent Change
# 9              BOPTEXP                      Exports           $, Millions                Percent Change
# 10             BOPTIMP                      Imports           $, Millions                Percent Change
# 11             TTLCONS        Construction Spending           $, Millions                Percent Change
# 12                  IR           Import Price Index                 Index                Percent Change
# 13            CPILFESL    Core Consumer Price Index                 Index                Percent Change
# 14            PCEPILFE         Core PCE Price Index                 Index                Percent Change
# 15               PCEPI              PCE Price Index                 Index                Percent Change
# 16              PERMIT             Building Permits    Thousands of Units           Change (Difference)
# 17                 TCU    Capacity Utilization Rate                     %           Change (Difference)
# 18              BUSINV         Business Inventories           $, Millions                Percent Change
# 19                  IQ           Export Price Index                 Index                Percent Change
# 20   GACDISA066MSFRBNY       Empire State Mfg Index                 Index    Levels (No Transformation)
# 21              PCEC96    Real Consumption Spending   Chained $, Billions                Percent Change
# 22  GACDFSA066MSFRBPHI   Philadelphia Fed Mfg Index                 Index    Levels (No Transformation)
# 23               GDPC1  Real Gross Domestic Product   Chained $, Billions  Percent Change (Annual Rate)
# 24              ULCNFB              Unit Labor Cost                 Index  Percent Change (Annual Rate)
# 2000-01-01 00:00:00
#
#
#
#
# Table 2: Data Summary
#
# N =     25 data series
# T = 198 observations from 2000-01-01 to 2016-06-01
#
#                                                  Observations Observation Time Range         Units  Frequency       mean         std         min        Min/Max Dates
# Payroll Employment [PAYEMS]                             197.0    Jan-2000 / May-2016  Level change    Monthly  66.568528  228.845888 -823.000000  Mar-2009 / May-2010
# Job Openings [JTSJOL]                                   184.0    Jan-2001 / Apr-2015  Level change    Monthly   5.717391  235.102272 -727.000000  Feb-2001 / Jan-2003
# Core Consumer Price Index [CPILFESL]                    197.0    Jan-2000 / May-2016         Index    Monthly   0.164624    0.080374   -0.112278  Jan-2010 / Jun-2001
# Core PCE Price Index [PCEPILFE]                         197.0    Jan-2000 / May-2016         Index    Monthly   0.142403    0.095315   -0.549946  Sep-2001 / Oct-2001
# PCE Price Index [PCEPI]                                 197.0    Jan-2000 / May-2016         Index    Monthly   0.151748    0.213714   -1.131262  Nov-2008 / Sep-2005
# Building Permits [PERMIT]                               197.0    Jan-2000 / May-2016  Level change    Monthly  -2.776650   60.898886 -259.000000  Jul-2008 / Jun-2008
# Capacity Utilization Rate [TCU]                         197.0    Jan-2000 / May-2016   Ppt. change    Monthly  -0.037056    0.534616   -3.400000  Sep-2008 / May-2010
# Business Inventories [BUSINV]                           196.0    Jan-2000 / Apr-2016         MoM %    Monthly   0.238283    0.588914   -2.112722  Dec-2008 / Mar-2011
# Export Price Index [IQ]                                 197.0    Jan-2000 / May-2016         Index    Monthly   0.100119    0.696120   -3.188880  Nov-2008 / Mar-2008
# Empire State Mfg Index [GACDISA066MSFRBNY]              180.0    Jul-2001 / Dec-2014         Index    Monthly   7.945167   14.689286  -34.530000  Feb-2009 / Apr-2004
# Real Consumption Spending [PCEC96]                      197.0    Jan-2000 / May-2016         MoM %    Monthly   0.184079    0.370637   -1.031872  Sep-2009 / Oct-2001
# Philadelphia Fed Mfg Index [GACDFSA066MSFRBPHI]         198.0    Jan-2000 / Jun-2016         Index    Monthly   4.890909   15.164557  -40.900000  Nov-2008 / Mar-2011
# Real Gross Domestic Product [GDPC1]                      65.0    Mar-2000 / May-2005      QoQ AR %  Quarterly   1.848733    2.500086   -8.186368  Dec-2008 / Jun-2000
# Unit Labor Cost [ULCNFB]                                 65.0    Mar-2000 / May-2005         Index  Quarterly   1.478009    5.408111  -12.305981  Mar-2009 / Mar-2000

# %%
# -------------------------------------------------Plot raw vs transformed data for a single series
fig_transformed = plot_transformed_data_one(Spec, X, Z, Time, series_id="INDPRO", show=False)
# fig_transformed.show()
fig_transformed

# %%
# -------------------------------------------------Run dynamic factor model (DFM)
print("Running Dynamic Factor Model (DFM)...")
ResObject = run(X, Spec, options)
# Out:
# Running Dynamic Factor Model (DFM)...
# creating file .pickles/ResDFM-iter_V-2016-06-29-M-5000_T-0.0001-hash-2c98201.pickle
# [CACHE FOUND] Loading previous results from cache...
# Function run took 0.0017 seconds to run.

# %%
# -------------------------------------------------Plot LogLik convergence
fig_loglik = plot_loglik(ResObject, Time, show=False)
fig_loglik.show()

# %%
# -------------------------------------------------Plot common factor and standardized data
fig_common = plot_common(ResObject, Time, series_id="INDPRO", show=False)
fig_common.show()

# %%
# -------------------------------------------------Plot projection of common factor onto series of interest
fig_projection = plot_projection_x_over_y(ResObject, X, Z, Time, series=["PAYEMS", "GDPC1"], show=False)
fig_projection.show()
