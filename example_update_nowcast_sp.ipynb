# %%
from dfm_sp import sp_update_nowcast , Options

series = "GDPC1"
period = "2016q4"
# 
vintage_old = "2016-12-16"
vintage_new = "2016-12-23"
sample_start = "2000-01-01"
country = "US"
spec_file_name = "Spec_US_example.xls"
max_iter = 5000

options_baseline = Options(

    vintage=vintage_old,
    max_iter=max_iter,
    spec_file_name=spec_file_name,
    threshold=1e-4,
    country=country,
    sample_start=sample_start,
    use_cache=True,
)

result_dict = sp_update_nowcast(options_baseline, vintage_new, series, period)
# Out:
# Executing Baseline for 2016-12-16...
#
#  Table 1: Model specification
#
#               SeriesID                   SeriesName                 Units  \
# 0               PAYEMS           Payroll Employment  Thousands of Persons
# 1               JTSJOL                 Job Openings             Thousands
# 2             CPIAUCSL         Consumer Price Index                 Index
# 3              DGORDER         Durable Goods Orders           $, Millions
# 4                RSAFS                 Retail Sales           $, Millions
# 5               UNRATE            Unemployment Rate                     %
# 6                HOUST               Housing Starts    Thousands of Units
# 7               INDPRO        Industrial Production                 Index
# 8              DSPIC96              Personal Income   Chained $, Billions
# 9              BOPTEXP                      Exports           $, Millions
# 10             BOPTIMP                      Imports           $, Millions
# ...

# %%
print(result_dict.keys())
# Out:
# dict_keys(['fig', 'real_impacts', 'data_released', 'news_table'])

# %%
result_dict['real_impacts']
# Out:
#           Forecast    Actual    Weight    Impact
# DGORDER  -1.832871 -4.598821  0.007409 -0.020493
# DSPIC96   0.174263 -0.050908  0.011456 -0.002580
# PCEPILFE  0.142310  0.004467  0.237833 -0.032784
# PCEPI     0.173086  0.041284  0.264582 -0.034872
# PCEC96    0.188655  0.144587  0.367998 -0.016217

# %%
result_dict['data_released']
# Out:
# array([False, False, False,  True, False, False, False, False,  True,
#        False, False, False, False, False,  True,  True, False, False,
#        False, False, False,  True, False, False, False])

# %%
result_dict['news_table']
# Out:
#                     Forecast    Actual    Weight    Impact
# PAYEMS                   NaN       NaN       NaN       NaN
# JTSJOL                   NaN       NaN       NaN       NaN
# CPIAUCSL                 NaN       NaN       NaN       NaN
# DGORDER            -1.832871 -4.598821  0.007409 -0.020493
# RSAFS                    NaN       NaN       NaN       NaN
# UNRATE                   NaN       NaN       NaN       NaN
# HOUST                    NaN       NaN       NaN       NaN
# INDPRO                   NaN       NaN       NaN       NaN
# DSPIC96             0.174263 -0.050908  0.011456 -0.002580
# BOPTEXP                  NaN       NaN       NaN       NaN
# BOPTIMP                  NaN       NaN       NaN       NaN
# TTLCONS                  NaN       NaN       NaN       NaN
# IR                       NaN       NaN       NaN       NaN
# CPILFESL                 NaN       NaN       NaN       NaN
# PCEPILFE            0.142310  0.004467  0.237833 -0.032784
# ...

# %%
result_dict['fig']
